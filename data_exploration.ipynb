# %%
import pandas as pd
import numpy as np

# %%
outcomes_df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2019/2019-07-09/wwc_outcomes.csv")
squads_df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2019/2019-07-09/squads.csv")
codes_df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2019/2019-07-09/codes.csv")

# %%
outcomes_df = pd.merge(left=outcomes_df, right=codes_df, how="left")

# %%
squads_df.head()
# Out:
#    squad_no country pos            player                   dob  age   caps  \
# 0         1      US  GK     Alyssa Naeher  1988-04-20T00:00:00Z   31   43.0
# 1         2      US  FW      Mallory Pugh  1998-04-29T00:00:00Z   21   50.0
# 2         3      US  MF         Sam Mewis  1992-10-09T00:00:00Z   26   47.0
# 3         4      US  DF  Becky Sauerbrunn  1985-06-06T00:00:00Z   34  155.0
# 4         5      US  DF     Kelley O'Hara  1988-08-04T00:00:00Z   30  115.0
#
#    goals                    club
# 0    0.0       Chicago Red Stars
# 1   15.0       Washington Spirit
# 2    9.0  North Carolina Courage
# 3    0.0             Utah Royals
# 4    2.0             Utah Royals

# %%
codes_df.shape
# Out:
# (212, 2)

# %%
outcomes_df.head(60)
# Out:
#     year team  score                round  yearly_game_id  team_num  \
# 0   1991  CHN      4                Group               1         1
# 1   1991  NOR      0                Group               1         2
# 2   1991  DEN      3                Group               2         1
# 3   1991  NZL      0                Group               2         2
# 4   1991  JPN      0                Group               3         1
# 5   1991  BRA      1                Group               3         2
# 6   1991  GER      4                Group               4         1
# 7   1991  NGA      0                Group               4         2
# 8   1991  SWE      2                Group               5         1
# 9   1991  USA      3                Group               5         2
# 10  1991  TPE      0                Group               6         1
# 11  1991  ITA      5                Group               6         2
# 12  1991  NOR      4                Group               7         1
# ...
